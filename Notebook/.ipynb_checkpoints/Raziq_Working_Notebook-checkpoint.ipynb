# %%
import yt as yt

# %%
# ds = yt.load("~/Documents/Research with Camille/sizmbhloz-clref04SNth-rs9_a0.9011/sizmbhloz-clref04SNth-rs9_a0.9011.art")
ds = yt.load("~/Data/rei20c1_a0.1667/rei20c1_a0.1667.art")
# Out:
# yt : [WARNING  ] 2019-07-01 16:32:04,446 DeltaDC != 0, which implies auni != abox.  Be sure you understand which expansion parameter is appropriate for your use! (Gnedin, Kravtsov, & Rudd 2011)
# yt : [INFO     ] 2019-07-01 16:32:04,481 Parameters: current_time              = 1176744983.2874885 yr
# yt : [INFO     ] 2019-07-01 16:32:04,482 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2019-07-01 16:32:04,483 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-07-01 16:32:04,484 Parameters: domain_right_edge         = [128. 128. 128.]
# yt : [INFO     ] 2019-07-01 16:32:04,485 Parameters: cosmological_simulation   = True
# yt : [INFO     ] 2019-07-01 16:32:04,486 Parameters: current_redshift          = 4.998522436346952
# yt : [INFO     ] 2019-07-01 16:32:04,487 Parameters: omega_lambda              = 0.6964000165462494
# yt : [INFO     ] 2019-07-01 16:32:04,488 Parameters: omega_matter              = 0.3035999834537506
# yt : [INFO     ] 2019-07-01 16:32:04,489 Parameters: hubble_constant           = 0.6814000010490417

# %%
slc = yt.SlicePlot(ds, 'z','density')
# slc.zoom(10)
slc.show()
slc.save()
# Out:
# yt : [INFO     ] 2019-07-01 16:34:03,125 Created 4926 chunks for ARTIO
# yt : [INFO     ] 2019-07-01 16:34:03,839 xlim = 0.000000 128.000000
# yt : [INFO     ] 2019-07-01 16:34:03,844 ylim = 0.000000 128.000000
# yt : [INFO     ] 2019-07-01 16:34:03,846 xlim = 0.000000 128.000000
# yt : [INFO     ] 2019-07-01 16:34:03,847 ylim = 0.000000 128.000000
# yt : [INFO     ] 2019-07-01 16:34:03,850 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2019-07-01 16:34:05,672 Saving plot rei20c1_a0.1667.art_Slice_z_density.png
# ['rei20c1_a0.1667.art_Slice_z_density.png']

# %%
for i in sorted(ds.field_list):
    print(i)
# Out:
# ('N-BODY', 'MASS')
# ('N-BODY', 'PID')
# ('N-BODY', 'POSITION_X')
# ('N-BODY', 'POSITION_Y')
# ('N-BODY', 'POSITION_Z')
# ('N-BODY', 'SPECIES')
# ('N-BODY', 'TIMESTEP')
# ('N-BODY', 'VELOCITY_X')
# ('N-BODY', 'VELOCITY_Y')
# ('N-BODY', 'VELOCITY_Z')
# ('STAR', 'BIRTH_TIME')
# ('STAR', 'INITIAL_MASS')
# ('STAR', 'MASS')
# ('STAR', 'METALLICITY_SNII')
# ('STAR', 'METALLICITY_SNIa')
# ('STAR', 'PID')
# ('STAR', 'POSITION_X')
# ('STAR', 'POSITION_Y')
# ('STAR', 'POSITION_Z')
# ('STAR', 'SPECIES')
# ('STAR', 'TIMESTEP')
# ('STAR', 'VELOCITY_X')
# ('STAR', 'VELOCITY_Y')
# ('STAR', 'VELOCITY_Z')
# ('all', 'MASS')
# ('all', 'PID')
# ('all', 'POSITION_X')
# ('all', 'POSITION_Y')
# ('all', 'POSITION_Z')
# ('all', 'SPECIES')
# ('all', 'TIMESTEP')
# ('all', 'VELOCITY_X')
# ('all', 'VELOCITY_Y')
# ('all', 'VELOCITY_Z')
# ('artio', 'HVAR_GAMMA')
# ('artio', 'HVAR_GAS_DENSITY')
# ('artio', 'HVAR_GAS_ENERGY')
# ('artio', 'HVAR_INTERNAL_ENERGY')
# ('artio', 'HVAR_METAL_DENSITY_II')
# ('artio', 'HVAR_METAL_DENSITY_Ia')
# ('artio', 'HVAR_MOMENTUM_X')
# ('artio', 'HVAR_MOMENTUM_Y')
# ('artio', 'HVAR_MOMENTUM_Z')
# ('artio', 'HVAR_PRESSURE')
# ('artio', 'VAR_POTENTIAL')
# ('artio', 'VAR_POTENTIAL_HYDRO')

# %%
plot = yt.ProfilePlot(ds, "density", ["temperature"])
plot.show()
plot.save("Density vs. Temperature test plot")
# Out:
# yt : [INFO     ] 2019-07-01 16:35:09,014 Created 2048 chunks for ARTIO
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2019-07-01 16:37:41,984 Saving Density vs. Temperature test plot_1d-Profile_density_temperature.png
# yt : [INFO     ] 2019-07-01 16:37:41,985 Saving plot Density vs. Temperature test plot_1d-Profile_density_temperature.png
# ['Density vs. Temperature test plot_1d-Profile_density_temperature.png']
