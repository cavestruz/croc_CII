# %%
import yt as yt

# %%
ds = yt.load("~/Documents/Research with Camille/sizmbhloz-clref04SNth-rs9_a0.9011/sizmbhloz-clref04SNth-rs9_a0.9011.art")
# Out:
# yt : [INFO     ] 2019-06-19 13:40:03,979 Parameters: current_time              = 12042349585.44105 yr
# yt : [INFO     ] 2019-06-19 13:40:03,980 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2019-06-19 13:40:03,981 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2019-06-19 13:40:03,983 Parameters: domain_right_edge         = [128. 128. 128.]
# yt : [INFO     ] 2019-06-19 13:40:03,985 Parameters: cosmological_simulation   = True
# yt : [INFO     ] 2019-06-19 13:40:03,985 Parameters: current_redshift          = 0.10980115776994159
# yt : [INFO     ] 2019-06-19 13:40:03,987 Parameters: omega_lambda              = 0.7
# yt : [INFO     ] 2019-06-19 13:40:03,988 Parameters: omega_matter              = 0.3
# yt : [INFO     ] 2019-06-19 13:40:03,989 Parameters: hubble_constant           = 0.7

# %%
slc = yt.SlicePlot(ds, 'z','density')
slc.zoom(10)
slc.show()
slc.save()
# Out:
# yt : [INFO     ] 2019-06-19 14:38:22,708 Created 4926 chunks for ARTIO
# yt : [INFO     ] 2019-06-19 14:38:22,976 xlim = 0.000000 128.000000
# yt : [INFO     ] 2019-06-19 14:38:22,977 ylim = 0.000000 128.000000
# yt : [INFO     ] 2019-06-19 14:38:22,979 xlim = 0.000000 128.000000
# yt : [INFO     ] 2019-06-19 14:38:22,980 ylim = 0.000000 128.000000
# yt : [INFO     ] 2019-06-19 14:38:22,983 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# yt : [INFO     ] 2019-06-19 14:38:23,374 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2019-06-19 14:38:23,938 Saving plot sizmbhloz-clref04SNth-rs9_a0.9011.art_Slice_z_density.png
# ['sizmbhloz-clref04SNth-rs9_a0.9011.art_Slice_z_density.png']

# %%
for i in sorted(ds.field_list):
  print(i)
# Out:
# ('N-BODY', 'MASS')
# ('N-BODY', 'PID')
# ('N-BODY', 'POSITION_X')
# ('N-BODY', 'POSITION_Y')
# ('N-BODY', 'POSITION_Z')
# ('N-BODY', 'SPECIES')
# ('N-BODY', 'TIMESTEP')
# ('N-BODY', 'VELOCITY_X')
# ('N-BODY', 'VELOCITY_Y')
# ('N-BODY', 'VELOCITY_Z')
# ('STAR', 'BIRTH_TIME')
# ('STAR', 'INITIAL_MASS')
# ('STAR', 'MASS')
# ('STAR', 'METALLICITY_SNII')
# ('STAR', 'METALLICITY_SNIa')
# ('STAR', 'PID')
# ('STAR', 'POSITION_X')
# ('STAR', 'POSITION_Y')
# ('STAR', 'POSITION_Z')
# ('STAR', 'SPECIES')
# ('STAR', 'TIMESTEP')
# ('STAR', 'VELOCITY_X')
# ('STAR', 'VELOCITY_Y')
# ('STAR', 'VELOCITY_Z')
# ('all', 'MASS')
# ('all', 'PID')
# ('all', 'POSITION_X')
# ('all', 'POSITION_Y')
# ('all', 'POSITION_Z')
# ('all', 'SPECIES')
# ('all', 'TIMESTEP')
# ('all', 'VELOCITY_X')
# ('all', 'VELOCITY_Y')
# ('all', 'VELOCITY_Z')
# ('artio', 'HVAR_GAMMA')
# ('artio', 'HVAR_GAS_DENSITY')
# ('artio', 'HVAR_GAS_ENERGY')
# ('artio', 'HVAR_INTERNAL_ENERGY')
# ('artio', 'HVAR_METAL_DENSITY_II')
# ('artio', 'HVAR_METAL_DENSITY_Ia')
# ('artio', 'HVAR_MOMENTUM_X')
# ('artio', 'HVAR_MOMENTUM_Y')
# ('artio', 'HVAR_MOMENTUM_Z')
# ('artio', 'HVAR_PRESSURE')
# ('artio', 'VAR_POTENTIAL')
# ('artio', 'VAR_POTENTIAL_HYDRO')

# %%
plot = yt.ProfilePlot(ds, "density", ["temperature"])
plot.show()
plot.save()
# Out:
# yt : [INFO     ] 2019-06-19 14:39:16,349 Created 2048 chunks for ARTIO
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
# yt : [INFO     ] 2019-06-19 14:39:28,542 Saving sizmbhloz-clref04SNth-rs9_a0.9011.art_1d-Profile_density_temperature.png
# yt : [INFO     ] 2019-06-19 14:39:28,543 Saving plot sizmbhloz-clref04SNth-rs9_a0.9011.art_1d-Profile_density_temperature.png
# ['sizmbhloz-clref04SNth-rs9_a0.9011.art_1d-Profile_density_temperature.png']
